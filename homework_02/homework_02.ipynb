# %% [markdown]
# # Домашнее задание: Управляющие конструкции

# %% [markdown]
# ## Задание 1: Получение однозначного числа
#
# Пользователь вводит целое число, программа складывает все цифры числа, с полученным числом — то же самое, и так до тех пор, пока не получится однозначное число.
#
# <br>
#
# **Примеры:**
# * `545   -> 5`
# * `12345 -> 6`

# %%
number = input('Введите целое число: ')

is_single = False
while (not is_single):
    summary = 0
    for digit in number:
        summary += int(digit)
    number = str(summary)

    if summary < 10:
        is_single = True

print(number)

# %% [markdown]
# ## Задание 2: Кинотеатр
#
# Дан список списков, каждый вложенный список состоит из 1 и 0, количество вложенных списков — количество рядов. Пользователь вводит, сколько билетов ему требуется. Программа должна найти ряд, где можно приобрести нужное количество билетов (места должны быть рядом). Если таких рядов несколько, то ближайший к экрану (ближайшим считается нулевой ряд). Если таких мест нет, то вывести False.
#
# <br>
#
# **Примеры:**
# * `[[0,1,1,0], [1,0,0,0], [0,1,0,0]], 2 -> 1`
# * `[[0,1,1,0], [1,0,1,0], [1,1,0,1]], 2 -> False`

# %%
input_value = int(input('Введите кол-во билетов: '))

cinema_places = [[0, 1, 1, 0], [1, 0, 0, 0], [0, 1, 0, 1]]

result = None

for row in cinema_places:

    count_free_places = 0
    for place in row:
        if count_free_places == 0 and place == 0:
            count_free_places += 1
        elif count_free_places > 0 and place == 0:
            count_free_places += 1
        elif count_free_places < input_value and place == 1:
            count_free_places = 0

    if count_free_places >= input_value:
        result = count_free_places // input_value
        break

print(False if result is None else result)

# %% [markdown]
# ## Задание 3: Алгоритм RLE
#
# Необходимо написать упрощенную версию алгоритма RLE.
# Алгоритм RLE объединяет подряд идущие символы в коэффициент и символ.
#
# <br>
#
# **Примеры:**
# * `asssdddsssddd -> 1a3s3d3s3d`
# * `aaabbbbccccc  -> 3a4b5c`
# * `abcba         -> 1a1b1c1b1a`

# %%
input_value = input('Введите строку: ')


previous = None
repeated_count = 0

result=''

for char in input_value:
    if previous is None:
        previous = char


    if previous == char:
        repeated_count+=1
    else:
        result += str(repeated_count) + previous
        previous = char
        repeated_count = 1


result+=str(repeated_count)+previous

print(result)

# %% [markdown]
# ## Задание 4: Шифр Цезаря
#
# Реализуйте программу для шифрования текста с помощью шифра Цезаря.
# Шифр Цезаря — это метод шифрования, при котором каждая буква в тексте заменяется буквой, стоящей на фиксированное число позиций дальше в алфавите.
#
# ### Требования
# 1. Программа должна принимать на вход:
#    - Строку текста для шифрования
#    - Ключ шифра (число от 0 до 25)
#
# 2. Правила шифрования:
#    - Шифруются только латинские буквы (a-z, A-Z)
#    - Сохраняется регистр букв (заглавные остаются заглавными)
#    - Пробелы, цифры и знаки препинания остаются без изменений
#    - Сдвиг циклический (после 'z' идет 'a', после 'Z' идет 'A')
#
# ### Примеры
#
# * `"Hello World", 3      -> "Khoor Zruog"`
# * `"Python is great!", 5 -> "Udymts nx lwjfy!"`
# * `"XYZ abc", 3          -> "ABC def"`
# * `"Test 123", 1         -> "Uftu 123"`
#
# ### Алгоритм
# * Для каждого символа в строке:
#    - Если это латинская буква, найти её позицию в алфавите
#    - Добавить к позиции значение ключа
#    - Если результат больше 25, использовать остаток от деления на 26
#    - Преобразовать обратно в букву, сохранив регистр
#    - Если это не буква, оставить символ без изменений

# %%
input_value = input('Введите строку для шифрования: ')

key = int(input('Введите ключ шифрования: '))

result = ''

for char in input_value:
    is_founded = False

    for i in range(ord('a'), ord('z') + 1):
        if char == chr(i):
            index_new_char = i + key

            if index_new_char > 122:
                result += chr(index_new_char - 26)
            else:
                result += chr(index_new_char)
            is_founded = True
            break

    if is_founded == False:
        for i in range(ord('A'), ord('Z') + 1):
            if char == chr(i):
                index_new_char = i + key
                if index_new_char > 90:
                    result += chr(index_new_char - 26)
                else:
                    result += chr(index_new_char)
                is_founded = True
                break

    if is_founded == False:
        result += char

print(result)

# %% [markdown]
# ## Задание 5: Табель успеваемости
#
# Пользователь в бесконечном цикле (пока не будет введена пустая строка) вводит строки вида: 'название предмета' 'фамилия ученика' 'оценка'. После окончания ввода программа выводит в консоль название предмета, далее список учеников и все их оценки в виде таблицы.
#
# <br>
#
# **Примеры:**
#
# <br>
#
# *Ввод:*
# ```python
# Математика Иванов  5
# Математика Иванов  4
# Литература Иванов  3
# Математика Петров  5
# Литература Сидоров 3
# Литература Петров  5
# Литература Иванов  4
# Математика Сидоров 3
# Математика Петров  5
# ```
#
# <br>
#
# *Результат:*
# ```python
# Математика # вводим название предмета
#
# # выводим список учеников и их оценки
# Иванов  5 4
# Петров  5 5
# Сидоров 3
# ```
#
# ```python
# Литература # вводим название предмета
#
# # выводим список учеников и их оценки
# Иванов  3 4
# Сидоров 3
# Петров  5
# ```

# %%
is_break = False
dictionary = {}
while not is_break:
    input_value = input("'название предмета' 'фамилия ученика' 'оценка': ")
    if (input_value == ''):
        is_break = True

    if not is_break:
        split_input_value = input_value.split(' ')
        lesson = split_input_value[0]
        surname = split_input_value[1]
        marks = split_input_value[2]
        if dictionary.get(lesson) is None:
            dictionary[lesson] = {surname: [marks]}
        else:
            var = dictionary[lesson]
            if var.get(surname) is None:
                var[surname] = [marks]
            else:
                var[surname] += [marks]

for key, value in dictionary.items():
    print(key)
    print('# выводим список учеников и их оценки')
    for surname, m in value.items():
        print(surname + ' ' + ", ".join(m))
